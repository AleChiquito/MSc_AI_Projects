# %%
import pandas as pd

# %%
data = pd.read_csv('ligue1_france_2022_2023.csv')
data.head(5)
# Out:
#                                                                                                                            MatchId  \
# 70850 Journ�e 10 STADE RAYMOND-KOPA                    7970.0  DIM. 9 OCTOBRE 2022- 15:00 ANGERS SCO          RC STRASBOURG ALSACE
# 70851 Journ�e 10 STADE FRANCIS-LE BL�                  9819.0  DIM. 9 OCTOBRE 2022- 15:00 STADE BRESTOIS 29             FC LORIENT
# 70852 Journ�e 10 STADE GABRIEL-MONTPIED                11119.0 DIM. 9 OCTOBRE 2022- 15:00 CLERMONT FOOT 63              AJ AUXERRE
# 70853 Journ�e 10 DECATHLON ARENA � STADE PIERRE-MAUROY 48527.0 DIM. 9 OCTOBRE 2022- 20:45 LOSC LILLE                       RC LENS
# 70854 Journ�e 10 GROUPAMA STADIUM                      41495.0 VEN. 7 OCTOBRE 2022- 21:00 OLYMPIQUE LYONNAIS           TOULOUSE FC
#
#                                                                                                               Journee  \
# ...
