# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen
Img1 = cv2.imread('image.png')
Img1 = cv2.cvtColor(Img1, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB
Img1 = Img1.astype(np.float32) / 255.0  # Convertir a punto flotante y escalar al rango [0, 1]

# %%
# Mostrar la imagen original y su histograma
plt.figure()
plt.subplot(2, 2, 1)
plt.imshow(Img1)
plt.title('Imagen original')
plt.axis('off')
plt.subplot(2, 2, 2)
plt.hist(Img1.ravel(), bins=256, range=(0, 1), color='k')
plt.title('Histograma')
plt.axis('off')
# Out:
# (-0.05, 1.05, 0.0, 1024984.8)

# %%
# Aplicar corrección gamma con diferentes valores de gamma
for gamma in np.arange(0, 4.2, 0.2):
    ImgRes = np.power(Img1, 1/gamma)
    ImgRes = np.clip(ImgRes, 0, 1)  # Asegurar que los valores estén en el rango [0, 1]
    plt.subplot(2, 2, 3)
    plt.imshow(ImgRes)
    plt.title('Imagen Resultante')
    plt.axis('off')
    plt.subplot(2, 2, 4)
    plt.hist(ImgRes.ravel(), bins=256, range=(0, 1), color='k')
    plt.title('Histograma Resultante')
    plt.axis('off')
    plt.pause(0.5)

plt.show()
# Out:
# /var/folders/qc/0kbw0c7n6cg2vt6xf9gp3g2h0000gn/T/ipykernel_45228/2286906369.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   ImgRes = np.power(Img1, 1/gamma)
