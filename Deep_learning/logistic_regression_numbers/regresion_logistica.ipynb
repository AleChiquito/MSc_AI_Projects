# %% [markdown]
# Graficando función Sigmoide

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
z = np.linspace(-10,10,100)
f_x = 1/ (1+ np.exp(-z))

# %%
plt.plot(z,f_x)plt.show()

# %%
import math
x = np.linspace(0,1,100)
j_0 = - np.log(x)
# Out:
# /var/folders/qc/0kbw0c7n6cg2vt6xf9gp3g2h0000gn/T/ipykernel_6071/3926964045.py:3: RuntimeWarning: divide by zero encountered in log
#   j_0 = - np.log(x)

# %%
plt.plot(x,j_0)
plt.show()

# %%
x = np.linspace(0,1,100)
j_0 = - np.log((1-x))
# Out:
# /var/folders/qc/0kbw0c7n6cg2vt6xf9gp3g2h0000gn/T/ipykernel_6071/3442976505.py:2: RuntimeWarning: divide by zero encountered in log
#   j_0 = - np.log((1-x))

# %%
plt.plot(x,j_0)
plt.show()
